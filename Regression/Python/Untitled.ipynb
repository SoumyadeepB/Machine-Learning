# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
column_names = ['x1','x2','y']
data = pd.read_csv('dataLinReg2D.txt',delimiter=" ",names=column_names)

# %%
data
# Out:
#           x1        x2         y
# 0   0.974633 -0.792363 -1.558240
# 1   0.322351  1.803400  1.889100
# 2   1.355890  0.389593  0.114214
# 3   0.085973 -1.069300 -2.029480
# 4  -0.643600 -0.400372 -1.432230
# 5  -0.885820  0.602299 -0.059078
# 6  -0.057270 -0.680160 -1.621270
# 7   1.316500 -0.570268 -1.070970
# 8  -1.226900  0.037207 -0.670011
# 9  -0.307733 -0.217767 -1.077600
# 10  2.019610 -0.143457 -0.310584
# 11 -0.346529 -0.474998 -1.624180
# 12  0.624072 -0.437087 -1.249660
# 13  1.503350  1.333490  1.517220
# 14  1.008320  0.019365 -0.443850
# 15  2.617060  1.876670  2.598650
# 16 -2.266520 -0.032136 -1.292840
# 17  1.308940  2.116070  2.475440
# 18  1.090920  1.043120  1.040460
# 19  1.200460  0.469415  0.352557
# 20  0.780383  0.011171 -0.463614
# 21 -0.100540 -1.402420 -2.611380
# 22  1.217260  1.066920  1.172180
# 23  2.330330  0.044417 -0.060376
# 24  0.403800  1.443550  1.452600
# 25 -1.350110 -0.320975 -1.572200
# 26 -1.522640 -0.050186 -1.125420
# ...
